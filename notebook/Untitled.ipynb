# %%
import pandas as pd

# %%
data1 = pd.read_csv('URL/training_final.csv')
data2 = pd.read_csv('URL/training_data.csv').drop(columns=['Label'])
data = pd.concat([data2, data1], axis=1)

# %%
data[data['Label'] == 0].sample(n=1).to_csv('url_sample.csv', index=False)

# %%
x = data[(data['numDash'] != 0) & (data['Label'] == 1)].sample(n=1)

# %%
# data[(data['numHash'] != 0) & (data['Label'] == 0)]
x.to_csv('url_sample.csv', index=False)
# x

# %%
data1 = pd.read_csv('Dataset/File Path/full_data.csv')
data2 = pd.read_csv('Dataset/File Path/training_final.csv').drop(columns=['Label'])
data = pd.concat([data1, data2], axis=1)

# %%
x = data[data['label'] == 1].sample(n=1)

# %%
x.to_csv('url_sample.csv', index=False)
x
# Out:
#                                  process_path  label       d_0      d_1  \
# 4843  C:\windows\appdiagnostics\pcrecpp-0.dll      1  1.090683 -0.19094
#
#            d_2       d_3       d_4       d_5       d_6      d_7  ...  \
# 4843  1.085378 -0.183799 -0.036486 -0.322814  0.781239  0.82655  ...
#
#          d_290     d_291     d_292     d_293     d_294     d_295     d_296  \
# 4843  0.611242  0.512714  0.472557 -0.250401 -0.091016 -0.877232 -0.083051
#
#          d_297     d_298     d_299
# 4843 -0.198138 -0.345721  0.754757
#
# [1 rows x 302 columns]

# %%
data1 = pd.read_csv('Dataset/Event/event.csv')
data2 = pd.read_csv('Dataset/Event/training_final.csv').drop(columns=['Label'])
data = pd.concat([data1, data2], axis=1)

# %%
x = data[(data['label'] == 0) ]

# %%
x.to_csv('url_sample.csv', index=False)

# %%
x
# Out:
#                   MAC_id         Type  \
# 36422  18-66-DA-09-F4-FD  Persistence
# 36423  4C-52-62-A7-BB-EC  Persistence
# 36424  50-9A-4C-02-B4-0A  Persistence
# 36425  50-9A-4C-02-B4-0A  Persistence
# 36426  8C-EC-4B-56-40-73  Persistence
# ...                  ...          ...
# 45777  E4-7F-B2-16-BC-FE          USB
# 45778  EC-A8-6B-74-CB-67          USB
# 45779  EC-A8-6B-74-CB-67          USB
# 45780  F8-BC-12-57-7A-6C          USB
# 45781  FC-08-4A-6D-2B-39          USB
#
#                                                     Info  label   0   1   2  \
# 36422           c:\users\huong baby\desktop\unikeynt.exe      0 NaN NaN NaN
# 36423      c:\users\k4r0fi\downloads\unikey\unikeynt.exe      0 NaN NaN NaN
# 36424  c:\users\tran manh\desktop\710201795421am_unik...      0 NaN NaN NaN
# 36425              c:\program files\ta-21\nextavgui.exe       0 NaN NaN NaN
# 36426           d:\unikey43rc3-180702-win64\unikeynt.exe      0 NaN NaN NaN
# ...
